# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
matches_response = requests.get("https://www.cricbuzz.com/cricket-series/9325/icc-champions-trophy-2025/matches")

# %%
matches_parsed_html = BeautifulSoup(matches_response.content, features="lxml")
with open ("match.txt", "w") as fp:
    for item in matches_parsed_html.find_all('div', attrs={'class':'cb-col-60 cb-col cb-srs-mtchs-tm'}):
        fp.write(str(item) + "\n")

# %%
urls = [line.strip() for line in open("match_list", "r")]
# urls[-1]
urls
# Out:
# ['https://www.cricbuzz.com/live-cricket-scorecard/112395/nz-vs-pak-1st-match-group-a-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112402/ban-vs-ind-2nd-match-group-a-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112409/rsa-vs-afg-3rd-match-group-b-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112413/eng-vs-aus-4th-match-group-b-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112420/pak-vs-ind-5th-match-group-a-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112427/ban-vs-nz-6th-match-group-a-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112430/aus-vs-rsa-7th-match-group-b-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112437/afg-vs-eng-8th-match-group-b-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112441/pak-vs-ban-9th-match-group-a-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112444/afg-vs-aus-10th-match-group-b-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112451/eng-vs-rsa-11th-match-group-b-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112455/ind-vs-nz-12th-match-group-a-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112462/ind-vs-aus-1st-semi-final-a1-v-b2-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112465/rsa-vs-nz-2nd-semi-final-b1-v-a2-icc-champions-trophy-2025']

# %%
urls[-2:]
# Out:
# ['https://www.cricbuzz.com/live-cricket-scorecard/112462/ind-vs-aus-1st-semi-final-a1-v-b2-icc-champions-trophy-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/112465/rsa-vs-nz-2nd-semi-final-b1-v-a2-icc-champions-trophy-2025']

# %%
for url in urls:
    print(url)
    response = requests.get(url)
    if response.status_code == 200:
        parsed_html = BeautifulSoup(response.content, features="lxml")
        items = parsed_html.find_all('div', attrs={'class':'cb-col cb-col-8 text-right text-bold'})
        for item in items:
            print(item.string, end='\n')
# Out:
# https://www.cricbuzz.com/live-cricket-scorecard/112395/nz-vs-pak-1st-match-group-a-icc-champions-trophy-2025
# R
# 107
# 10
# 1
# 10
# 118
# 61
# 0
# 0
# 2
# 1
# 2
# 0
# 0
# R
# 6
# 64
# 3
# 24
# 42
# 1
# 69
# 14
# 13
# 19
# 0
# 2
# 3
# 1
# 0
# 3
# 1
# https://www.cricbuzz.com/live-cricket-scorecard/112402/ban-vs-ind-2nd-match-group-a-icc-champions-trophy-2025
# R
# 25
# 0
# 0
# 5
# 100
# 0
# 68
# 18
# 0
# 3
# 0
# 5
# 3
# 2
# 0
# 0
# 0
# R
# 41
# 101
# 22
# 15
# 8
# 41
# 1
# 1
# 0
# 0
# 2
# https://www.cricbuzz.com/live-cricket-scorecard/112409/rsa-vs-afg-3rd-match-group-b-icc-champions-trophy-2025
# R
# 103
# 11
# 58
# 52
# 52
# 14
# 0
# 12
# 1
# 1
# 2
# 0
# 0
# 1
# R
# 10
# 17
# 16
# 90
# 0
# 18
# 8
# 13
# 18
# 9
# 0
# 1
# 2
# 3
# 2
# 1
# https://www.cricbuzz.com/live-cricket-scorecard/112413/eng-vs-aus-4th-match-group-b-icc-champions-trophy-2025
# R
# 10
# 165
# 15
# 68
# 3
# 23
# 14
# 8
# 21
# 1
# 0
# 3
# 0
# 1
# 2
# 0
# 2
# R
# 63
# 6
# 5
# 47
# 120
# 69
# 32
# 1
# 1
# 1
# 1
# 1
# 0
# 2

# %%
url = 'https://www.cricbuzz.com/api/cricket-match/91609/full-commentary/2'
response = requests.get(url=url) 
API_Data = response.json() 
for key in API_Data: 
    print(key)
# Out:
# matchId
# commentary
# commentarySnippetList
# matchDetails

# %%
for item in API_Data["commentary"]:
    print("inningsId:", item["inningsId"])
    for val in item["commentaryList"]:
        if "overSeparator" in val:
            out = val["overSeparator"]["runs"]
            out_type =  "Even" if out % 2 == 0 else "odd"
            print(val["overNumber"], out, out_type )
# Out:
# inningsId: 2
# 19.6 7 odd
# 18.6 11 odd
# 17.6 9 odd
# 16.6 7 odd
# 15.6 14 Even
# 14.6 11 odd
# 13.6 1 odd
# 12.6 2 Even
# 11.6 2 Even
# 10.6 3 odd
# 9.6 4 Even
# 8.6 6 Even
# 7.6 6 Even
# 6.6 9 odd
# 5.6 16 Even
# 4.6 15 odd
# 3.6 5 odd
# 2.6 2 Even
# 1.6 7 odd
# 0.6 2 Even

# %%
comm_url = [line.strip() for line in open("commentry_urls", "r")]
comm_url
# Out:
# ['https://www.cricbuzz.com/api/cricket-match/89731/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/89763/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91398/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91425/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91596/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/89731/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/89763/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91398/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91425/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91596/full-commentary/2']

# %%
for url in comm_url:
    response = requests.get(url=url)
    API_Data = response.json()
    for item in API_Data["commentary"]:
        print("inningsId:", item["inningsId"])
        for val in item["commentaryList"]:
            if "overSeparator" in val:
                out = val["overSeparator"]["runs"]
                out_type =  "Even" if out % 2 == 0 else "odd"
                print(val["overNumber"], out, out_type )
# Out:
# inningsId: 1
# 19.6 10 Even
# 18.6 1 odd
# 17.6 2 Even
# 16.6 1 odd
# 15.6 9 odd
# 14.6 5 odd
# 13.6 2 Even
# 12.6 6 Even
# 11.6 6 Even
# 10.6 6 Even
# 9.6 2 Even
# 8.6 10 Even
# 7.6 6 Even
# 6.6 13 odd
# 5.6 16 Even
# 4.6 10 Even
# 3.6 4 Even
# 2.6 3 odd
# 1.6 12 Even
# 0.6 1 odd
# inningsId: 1
# 19.6 32 Even
# 18.6 19 odd
# 17.6 16 Even
# 16.6 17 odd
# 15.6 12 Even
# 14.6 7 odd
# 13.6 8 Even
# 12.6 3 odd
# 11.6 7 odd
# 10.6 8 Even
# 9.6 13 odd
# 8.6 8 Even
# 7.6 4 Even
# 6.6 5 odd
# 5.6 15 odd
# 4.6 14 Even
# 3.6 13 odd
# 2.6 12 Even
# 1.6 14 Even
# 0.6 7 odd
# inningsId: 1
# 19.6 19 odd
# 18.6 9 odd
# 17.6 14 Even
# 16.6 5 odd
# 15.6 19 odd
# 14.6 9 odd
# 13.6 10 Even
# 12.6 4 Even
# 11.6 14 Even
# 10.6 4 Even
# 9.6 13 odd
# 8.6 9 odd
# 7.6 13 odd
# 6.6 10 Even
# 5.6 9 odd
# 4.6 7 odd
# 3.6 10 Even
# 2.6 4 Even
# 1.6 7 odd
# 0.6 7 odd
# inningsId: 1
# 19.6 26 Even
# 18.6 7 odd
# 17.6 12 Even
# 16.6 10 Even
# 15.6 2 Even
# 14.6 17 odd
# 13.6 22 Even
# 12.6 8 Even
# 11.6 10 Even
# 10.6 12 Even
# 9.6 15 odd
# 8.6 4 Even
# 7.6 9 odd
# 6.6 4 Even
# 5.6 10 Even
# 4.6 14 Even
# 3.6 6 Even
# 2.6 9 odd
# 1.6 3 odd
# 0.6 6 Even
# inningsId: 1
# 18.6 12 Even
# 17.6 2 Even
# 16.6 20 Even
# 15.6 5 odd
# 14.6 7 odd
# 13.6 12 Even
# 12.6 3 odd
# 11.6 15 odd
# 10.6 8 Even
# 9.6 11 odd
# 8.6 4 Even
# 7.6 8 Even
# 6.6 3 odd
# 5.6 6 Even
# 4.6 14 Even
# 3.6 9 odd
# 2.6 12 Even
# 1.6 2 Even
# 0.6 14 Even
# inningsId: 2
# 14.6 10 Even
# 13.6 7 odd
# 12.6 7 odd
# 11.6 3 odd
# 10.6 11 odd
# 9.6 5 odd
# 8.6 8 Even
# 7.6 10 Even
# 6.6 4 Even
# 5.6 2 Even
# 4.6 3 odd
# 3.6 11 odd
# 2.6 13 odd
# 1.6 7 odd
# 0.6 10 Even
# inningsId: 2
# 19.6 4 Even
# 18.6 21 odd
# 17.6 8 Even
# 16.6 19 odd
# 15.6 9 odd
# 14.6 6 Even
# 13.6 11 odd
# 12.6 16 Even
# 11.6 4 Even
# 10.6 13 odd
# 9.6 10 Even
# 8.6 15 odd
# 7.6 16 Even
# 6.6 7 odd
# 5.6 13 odd
# 4.6 9 odd
# 3.6 9 odd
# 2.6 4 Even
# 1.6 4 Even
# 0.6 7 odd
# inningsId: 2
# 14.6 7 odd
# 13.6 12 Even
# 12.6 18 Even
# 11.6 16 Even
# 10.6 24 Even
# 9.6 8 Even
# 8.6 11 odd
# 7.6 8 Even
# 6.6 12 Even
# 5.6 17 odd
# 4.6 23 odd
# 3.6 9 odd
# 2.6 14 Even
# 1.6 7 odd
# 0.6 2 Even
# inningsId: 2
# 19.6 13 odd
# 18.6 13 odd
# 17.6 6 Even
# 16.6 19 odd
# 15.6 3 odd
# 14.6 2 Even
# 13.6 6 Even
# 12.6 6 Even
# 11.6 10 Even
# 10.6 18 Even
# 9.6 9 odd
# 8.6 6 Even
# 7.6 5 odd
# 6.6 7 odd
# 5.6 10 Even
# 4.6 15 odd
# 3.6 13 odd
# 2.6 12 Even
# 1.6 8 Even
# 0.6 5 odd
# inningsId: 2
# 17.6 11 odd
# 16.6 3 odd
# 15.6 5 odd
# 14.6 9 odd
# 13.6 20 Even
# 12.6 8 Even
# 11.6 11 odd
# 10.6 4 Even
# 9.6 6 Even
# 8.6 7 odd
# 7.6 5 odd
# 6.6 3 odd
# 5.6 5 odd
# 4.6 3 odd
# 3.6 13 odd
# 2.6 9 odd
# 1.6 10 Even
# 0.6 6 Even
