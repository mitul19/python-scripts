# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
matches_response = requests.get("https://www.cricbuzz.com/cricket-series/9237/indian-premier-league-2025/matches")

# %%
matches_parsed_html = BeautifulSoup(matches_response.content, features="lxml")
with open ("match-ipl2025.txt", "w") as fp:
    for item in matches_parsed_html.find_all('div', attrs={'class':'cb-col-60 cb-col cb-srs-mtchs-tm'}):
        # print(item)
        a_tag = item.find('a')
        last_two_segments = a_tag['href'].split('/')[-2:]
        # print("https://www.cricbuzz.com/live-cricket-scorecard/" + "/".join(last_two_segments))
        fp.write("https://www.cricbuzz.com/live-cricket-scorecard/" + "/".join(last_two_segments) + "\n")

# %%
for item in matches_parsed_html.find_all('div', attrs={'class':'cb-col-60 cb-col cb-srs-mtchs-tm'}):
    # print(item)
    a_tag = item.find('a')
    last_two_segments = a_tag['href'].split('/')[-2:]
    print("https://www.cricbuzz.com/live-cricket-scorecard/" + "/".join(last_two_segments))
    break
# Out:
# https://www.cricbuzz.com/live-cricket-scorecard/114960/kkr-vs-rcb-1st-match-indian-premier-league-2025

# %%
urls = [line.strip() for line in open("match-ipl2025.txt", "r")]
# urls[7:12]
urls = urls[6:12]
urls
# Out:
# ['https://www.cricbuzz.com/live-cricket-scorecard/115005/srh-vs-lsg-7th-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/115012/csk-vs-rcb-8th-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/115014/gt-vs-mi-9th-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/115021/dc-vs-srh-10th-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/115030/rr-vs-csk-11th-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/115032/mi-vs-kkr-12th-match-indian-premier-league-2025']

# %%
for item in  urls: #[line.strip() for line in open("match-ipl2025.txt", "r")]:
    toss_response = requests.get(item)
    toss_html = BeautifulSoup(toss_response.content, features="lxml")
    print(toss_html.find_all('div', attrs={'class':'cb-col cb-col-73'})[0].string, toss_html.find_all('div', attrs={'class':'cb-col cb-col-73'})[2].string)
# Out:
#  SRH vs LSG, 7th Match, Indian Premier League 2025  	Lucknow Super Giants won the toss and opt to bowl
#  CSK vs RCB, 8th Match, Indian Premier League 2025  	Chennai Super Kings won the toss and opt to bowl
#  GT vs MI, 9th Match, Indian Premier League 2025  	Mumbai Indians won the toss and opt to bowl
#  DC vs SRH, 10th Match, Indian Premier League 2025  	Sunrisers Hyderabad won the toss and opt to bat
#  RR vs CSK, 11th Match, Indian Premier League 2025  	Chennai Super Kings won the toss and opt to bowl
#  MI vs KKR, 12th Match, Indian Premier League 2025  	Mumbai Indians won the toss and opt to bowl

# %%
# run_urls = urls[:3]
for url in urls:
    print(url)
    response = requests.get(url)
    if response.status_code == 200:
        parsed_html = BeautifulSoup(response.content, features="lxml")
        items = parsed_html.find_all('div', attrs={'class':'cb-col cb-col-8 text-right text-bold'})
        for item in items:
            print(item.string, end='\n')
# Out:
# https://www.cricbuzz.com/live-cricket-scorecard/115005/srh-vs-lsg-7th-match-indian-premier-league-2025
# R
# 47
# 6
# 0
# 32
# 26
# 36
# 2
# 18
# 12
# 1
# 3
# 4
# 1
# 1
# 1
# 1
# R
# 52
# 1
# 70
# 15
# 6
# 13
# 22
# 0
# 1
# 0
# 2
# 1
# 1
# 0
# https://www.cricbuzz.com/live-cricket-scorecard/115012/csk-vs-rcb-8th-match-indian-premier-league-2025
# R
# 32
# 31
# 27
# 51
# 10
# 12
# 22
# 0
# 0
# 1
# 1
# 0
# 3
# 0
# 2
# R
# 41
# 5
# 0
# 4
# 8
# 19
# 25
# 11
# 30
# 0
# 1
# 3
# 2
# 2
# 0
# 0
# https://www.cricbuzz.com/live-cricket-scorecard/115014/gt-vs-mi-9th-match-indian-premier-league-2025
# R
# 63
# 38
# 39
# 9
# 18
# 0
# 6
# 7
# 1
# 1
# 1
# 1
# 2
# 0
# 1
# R
# 8
# 6
# 39
# 48
# 3
# 11
# 18
# 18
# 2
# 1
# 0
# 0
# 1
# 2
# https://www.cricbuzz.com/live-cricket-scorecard/115021/dc-vs-srh-10th-match-indian-premier-league-2025
# R
# 1
# 22
# 2
# 0
# 74
# 32
# 4
# 2
# 9
# 5
# 1
# 5
# 0
# 0
# 0
# 1
# 3
# R
# 38
# 50
# 34
# 15
# 21
# 0
# 0
# 0
# 0
# 3
# 0
# https://www.cricbuzz.com/live-cricket-scorecard/115030/rr-vs-csk-11th-match-indian-premier-league-2025
# R
# 4
# 20
# 81
# 37
# 3
# 4
# 19
# 0
# 1
# 2
# 1
# 2
# 0
# 1
# 2
# 2
# 1
# R
# 0
# 23
# 63
# 18
# 9
# 32
# 16
# 11
# 1
# 0
# 1
# 0
# 4
# 0
# https://www.cricbuzz.com/live-cricket-scorecard/115032/mi-vs-kkr-12th-match-indian-premier-league-2025
# R
# 1
# 0
# 11
# 26
# 3
# 17
# 19
# 5
# 22
# 4
# 1
# 1
# 2
# 4
# 1
# 1
# 1
# R
# 13
# 62
# 16
# 27
# 0
# 0
# 0
# 2
# 0

# %%
url = 'https://www.cricbuzz.com/api/cricket-match/91609/full-commentary/2'
response = requests.get(url=url) 
API_Data = response.json() 
for key in API_Data: 
    print(key)
# Out:
# matchId
# commentary
# commentarySnippetList
# matchDetails

# %%
for item in API_Data["commentary"]:
    print("inningsId:", item["inningsId"])
    for val in item["commentaryList"]:
        if "overSeparator" in val:
            out = val["overSeparator"]["runs"]
            out_type =  "Even" if out % 2 == 0 else "odd"
            print(val["overNumber"], out, out_type )
# Out:
# inningsId: 2
# 19.6 7 odd
# 18.6 11 odd
# 17.6 9 odd
# 16.6 7 odd
# 15.6 14 Even
# 14.6 11 odd
# 13.6 1 odd
# 12.6 2 Even
# 11.6 2 Even
# 10.6 3 odd
# 9.6 4 Even
# 8.6 6 Even
# 7.6 6 Even
# 6.6 9 odd
# 5.6 16 Even
# 4.6 15 odd
# 3.6 5 odd
# 2.6 2 Even
# 1.6 7 odd
# 0.6 2 Even

# %%
comm_url = [line.strip() for line in open("commentry_urls", "r")]
comm_url
# Out:
# ['https://www.cricbuzz.com/api/cricket-match/89731/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/89763/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91398/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91425/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91596/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/89731/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/89763/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91398/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91425/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91596/full-commentary/2']

# %%
for url in comm_url:
    response = requests.get(url=url)
    API_Data = response.json()
    for item in API_Data["commentary"]:
        print("inningsId:", item["inningsId"])
        for val in item["commentaryList"]:
            if "overSeparator" in val:
                out = val["overSeparator"]["runs"]
                out_type =  "Even" if out % 2 == 0 else "odd"
                print(val["overNumber"], out, out_type )
# Out:
# inningsId: 1
# 19.6 10 Even
# 18.6 1 odd
# 17.6 2 Even
# 16.6 1 odd
# 15.6 9 odd
# 14.6 5 odd
# 13.6 2 Even
# 12.6 6 Even
# 11.6 6 Even
# 10.6 6 Even
# 9.6 2 Even
# 8.6 10 Even
# 7.6 6 Even
# 6.6 13 odd
# 5.6 16 Even
# 4.6 10 Even
# 3.6 4 Even
# 2.6 3 odd
# 1.6 12 Even
# 0.6 1 odd
# inningsId: 1
# 19.6 32 Even
# 18.6 19 odd
# 17.6 16 Even
# 16.6 17 odd
# 15.6 12 Even
# 14.6 7 odd
# 13.6 8 Even
# 12.6 3 odd
# 11.6 7 odd
# 10.6 8 Even
# 9.6 13 odd
# 8.6 8 Even
# 7.6 4 Even
# 6.6 5 odd
# 5.6 15 odd
# 4.6 14 Even
# 3.6 13 odd
# 2.6 12 Even
# 1.6 14 Even
# 0.6 7 odd
# inningsId: 1
# 19.6 19 odd
# 18.6 9 odd
# 17.6 14 Even
# 16.6 5 odd
# 15.6 19 odd
# 14.6 9 odd
# 13.6 10 Even
# 12.6 4 Even
# 11.6 14 Even
# 10.6 4 Even
# 9.6 13 odd
# 8.6 9 odd
# 7.6 13 odd
# 6.6 10 Even
# 5.6 9 odd
# 4.6 7 odd
# 3.6 10 Even
# 2.6 4 Even
# 1.6 7 odd
# 0.6 7 odd
# inningsId: 1
# 19.6 26 Even
# 18.6 7 odd
# 17.6 12 Even
# 16.6 10 Even
# 15.6 2 Even
# 14.6 17 odd
# 13.6 22 Even
# 12.6 8 Even
# 11.6 10 Even
# 10.6 12 Even
# 9.6 15 odd
# 8.6 4 Even
# 7.6 9 odd
# 6.6 4 Even
# 5.6 10 Even
# 4.6 14 Even
# 3.6 6 Even
# 2.6 9 odd
# 1.6 3 odd
# 0.6 6 Even
# inningsId: 1
# 18.6 12 Even
# 17.6 2 Even
# 16.6 20 Even
# 15.6 5 odd
# 14.6 7 odd
# 13.6 12 Even
# 12.6 3 odd
# 11.6 15 odd
# 10.6 8 Even
# 9.6 11 odd
# 8.6 4 Even
# 7.6 8 Even
# 6.6 3 odd
# 5.6 6 Even
# 4.6 14 Even
# 3.6 9 odd
# 2.6 12 Even
# 1.6 2 Even
# 0.6 14 Even
# inningsId: 2
# 14.6 10 Even
# 13.6 7 odd
# 12.6 7 odd
# 11.6 3 odd
# 10.6 11 odd
# 9.6 5 odd
# 8.6 8 Even
# 7.6 10 Even
# 6.6 4 Even
# 5.6 2 Even
# 4.6 3 odd
# 3.6 11 odd
# 2.6 13 odd
# 1.6 7 odd
# 0.6 10 Even
# inningsId: 2
# 19.6 4 Even
# 18.6 21 odd
# 17.6 8 Even
# 16.6 19 odd
# 15.6 9 odd
# 14.6 6 Even
# 13.6 11 odd
# 12.6 16 Even
# 11.6 4 Even
# 10.6 13 odd
# 9.6 10 Even
# 8.6 15 odd
# 7.6 16 Even
# 6.6 7 odd
# 5.6 13 odd
# 4.6 9 odd
# 3.6 9 odd
# 2.6 4 Even
# 1.6 4 Even
# 0.6 7 odd
# inningsId: 2
# 14.6 7 odd
# 13.6 12 Even
# 12.6 18 Even
# 11.6 16 Even
# 10.6 24 Even
# 9.6 8 Even
# 8.6 11 odd
# 7.6 8 Even
# 6.6 12 Even
# 5.6 17 odd
# 4.6 23 odd
# 3.6 9 odd
# 2.6 14 Even
# 1.6 7 odd
# 0.6 2 Even
# inningsId: 2
# 19.6 13 odd
# 18.6 13 odd
# 17.6 6 Even
# 16.6 19 odd
# 15.6 3 odd
# 14.6 2 Even
# 13.6 6 Even
# 12.6 6 Even
# 11.6 10 Even
# 10.6 18 Even
# 9.6 9 odd
# 8.6 6 Even
# 7.6 5 odd
# 6.6 7 odd
# 5.6 10 Even
# 4.6 15 odd
# 3.6 13 odd
# 2.6 12 Even
# 1.6 8 Even
# 0.6 5 odd
# inningsId: 2
# 17.6 11 odd
# 16.6 3 odd
# 15.6 5 odd
# 14.6 9 odd
# 13.6 20 Even
# 12.6 8 Even
# 11.6 11 odd
# 10.6 4 Even
# 9.6 6 Even
# 8.6 7 odd
# 7.6 5 odd
# 6.6 3 odd
# 5.6 5 odd
# 4.6 3 odd
# 3.6 13 odd
# 2.6 9 odd
# 1.6 10 Even
# 0.6 6 Even
