# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
matches_response = requests.get("https://www.cricbuzz.com/cricket-series/9237/indian-premier-league-2025/matches")

# %%
matches_parsed_html = BeautifulSoup(matches_response.content, features="lxml")
with open ("match-ipl2025.txt", "w") as fp:
    for item in matches_parsed_html.find_all('div', attrs={'class':'cb-col-60 cb-col cb-srs-mtchs-tm'}):
        # print(item)
        a_tag = item.find('a')
        last_two_segments = a_tag['href'].split('/')[-2:]
        # print("https://www.cricbuzz.com/live-cricket-scorecard/" + "/".join(last_two_segments))
        fp.write("https://www.cricbuzz.com/live-cricket-scorecard/" + "/".join(last_two_segments) + "\n")

# %%
for item in matches_parsed_html.find_all('div', attrs={'class':'cb-col-60 cb-col cb-srs-mtchs-tm'}):
    # print(item)
    a_tag = item.find('a')
    last_two_segments = a_tag['href'].split('/')[-2:]
    print("https://www.cricbuzz.com/live-cricket-scorecard/" + "/".join(last_two_segments))
    break
# Out:
# https://www.cricbuzz.com/live-cricket-scorecard/114960/kkr-vs-rcb-1st-match-indian-premier-league-2025

# %%
urls = [line.strip() for line in open("match-ipl2025.txt", "r")]
urls[3:6]
urls = urls[3:6]
urls
# Out:
# ['https://www.cricbuzz.com/live-cricket-scorecard/114985/dc-vs-lsg-4th-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/114987/gt-vs-pbks-5th-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/114996/rr-vs-kkr-6th-match-indian-premier-league-2025']

# %%
for item in [line.strip() for line in open("match-ipl2025.txt", "r")]:
    toss_response = requests.get(item)
    toss_html = BeautifulSoup(toss_response.content, features="lxml")
    print(toss_html.find_all('div', attrs={'class':'cb-col cb-col-73'})[0].string, toss_html.find_all('div', attrs={'class':'cb-col cb-col-73'})[2].string)
# Out:
#  KKR vs RCB, 1st Match, Indian Premier League 2025  	Royal Challengers Bengaluru won the toss and opt to bowl
#  SRH vs RR, 2nd Match, Indian Premier League 2025  	Rajasthan Royals won the toss and opt to bowl
#  CSK vs MI, 3rd Match, Indian Premier League 2025  	Chennai Super Kings won the toss and opt to bowl
#  DC vs LSG, 4th Match, Indian Premier League 2025  	Delhi Capitals won the toss and opt to bowl
#  GT vs PBKS, 5th Match, Indian Premier League 2025  	Gujarat Titans won the toss and opt to bowl
#  RR vs KKR, 6th Match, Indian Premier League 2025  	Kolkata Knight Riders won the toss and opt to bowl
#  SRH vs LSG, 7th Match, Indian Premier League 2025  None
#  CSK vs RCB, 8th Match, Indian Premier League 2025  None
#  GT vs MI, 9th Match, Indian Premier League 2025  None
#  DC vs SRH, 10th Match, Indian Premier League 2025  None
#  RR vs CSK, 11th Match, Indian Premier League 2025  None
#  MI vs KKR, 12th Match, Indian Premier League 2025  None
#  LSG vs PBKS, 13th Match, Indian Premier League 2025  None
#  RCB vs GT, 14th Match, Indian Premier League 2025  None
#  KKR vs SRH, 15th Match, Indian Premier League 2025  None
#  LSG vs MI, 16th Match, Indian Premier League 2025  None
#  CSK vs DC, 17th Match, Indian Premier League 2025  None
#  PBKS vs RR, 18th Match, Indian Premier League 2025  None
#  KKR vs LSG, 19th Match, Indian Premier League 2025  None
#  SRH vs GT, 20th Match, Indian Premier League 2025  None
#  MI vs RCB, 21st Match, Indian Premier League 2025  None
#  PBKS vs CSK, 22nd Match, Indian Premier League 2025  None
#  GT vs RR, 23rd Match, Indian Premier League 2025  None
#  RCB vs DC, 24th Match, Indian Premier League 2025  None
#  CSK vs KKR, 25th Match, Indian Premier League 2025  None
#  LSG vs GT, 26th Match, Indian Premier League 2025  None
#  SRH vs PBKS, 27th Match, Indian Premier League 2025  None
#  RR vs RCB, 28th Match, Indian Premier League 2025  None
#  DC vs MI, 29th Match, Indian Premier League 2025  None
#  LSG vs CSK, 30th Match, Indian Premier League 2025  None
#  PBKS vs KKR, 31st Match, Indian Premier League 2025  None
#  DC vs RR, 32nd Match, Indian Premier League 2025  None
#  MI vs SRH, 33rd Match, Indian Premier League 2025  None
#  RCB vs PBKS, 34th Match, Indian Premier League 2025  None
#  GT vs DC, 35th Match, Indian Premier League 2025  None
#  RR vs LSG, 36th Match, Indian Premier League 2025  None
#  PBKS vs RCB, 37th Match, Indian Premier League 2025  None
#  MI vs CSK, 38th Match, Indian Premier League 2025  None
#  KKR vs GT, 39th Match, Indian Premier League 2025  None
#  LSG vs DC, 40th Match, Indian Premier League 2025  None
#  SRH vs MI, 41st Match, Indian Premier League 2025  None
#  RCB vs RR, 42nd Match, Indian Premier League 2025  None
#  CSK vs SRH, 43rd Match, Indian Premier League 2025  None
#  KKR vs PBKS, 44th Match, Indian Premier League 2025  None
#  MI vs LSG, 45th Match, Indian Premier League 2025  None
#  DC vs RCB, 46th Match, Indian Premier League 2025  None
#  RR vs GT, 47th Match, Indian Premier League 2025  None
#  DC vs KKR, 48th Match, Indian Premier League 2025  None
#  CSK vs PBKS, 49th Match, Indian Premier League 2025  None
#  RR vs MI, 50th Match, Indian Premier League 2025  None
#  GT vs SRH, 51st Match, Indian Premier League 2025  None
#  RCB vs CSK, 52nd Match, Indian Premier League 2025  None
#  KKR vs RR, 53rd Match, Indian Premier League 2025  None
#  PBKS vs LSG, 54th Match, Indian Premier League 2025  None
#  SRH vs DC, 55th Match, Indian Premier League 2025  None
#  MI vs GT, 56th Match, Indian Premier League 2025  None
#  KKR vs CSK, 57th Match, Indian Premier League 2025  None
#  PBKS vs DC, 58th Match, Indian Premier League 2025  None
#  LSG vs RCB, 59th Match, Indian Premier League 2025  None
#  SRH vs KKR, 60th Match, Indian Premier League 2025  None
#  PBKS vs MI, 61st Match, Indian Premier League 2025  None
#  DC vs GT, 62nd Match, Indian Premier League 2025  None
#  CSK vs RR, 63rd Match, Indian Premier League 2025  None
#  RCB vs SRH, 64th Match, Indian Premier League 2025  None
#  GT vs LSG, 65th Match, Indian Premier League 2025  None
#  MI vs DC, 66th Match, Indian Premier League 2025  None
#  RR vs PBKS, 67th Match, Indian Premier League 2025  None
#  RCB vs KKR, 68th Match, Indian Premier League 2025  None
#  GT vs CSK, 69th Match, Indian Premier League 2025  None
#  LSG vs SRH, 70th Match, Indian Premier League 2025  None
#  TBC vs TBC, Qualifier 1, Indian Premier League 2025  None
#  TBC vs TBC, Eliminator, Indian Premier League 2025  None
#  TBC vs TBC, Qualifier 2, Indian Premier League 2025  None
#  TBC vs TBC, Final, Indian Premier League 2025  None

# %%
urls[:3]
# Out:
# ['https://www.cricbuzz.com/live-cricket-scorecard/114960/kkr-vs-rcb-1st-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/114967/srh-vs-rr-2nd-match-indian-premier-league-2025',
#  'https://www.cricbuzz.com/live-cricket-scorecard/114976/mi-vs-csk-3rd-match-indian-premier-league-2025']

# %%
# run_urls = urls[:3]
for url in urls:
    print(url)
    response = requests.get(url)
    if response.status_code == 200:
        parsed_html = BeautifulSoup(response.content, features="lxml")
        items = parsed_html.find_all('div', attrs={'class':'cb-col cb-col-8 text-right text-bold'})
        for item in items:
            print(item.string, end='\n')
# Out:
# https://www.cricbuzz.com/live-cricket-scorecard/114985/dc-vs-lsg-4th-match-indian-premier-league-2025
# R
# 15
# 72
# 75
# 0
# 27
# 4
# 0
# 9
# 0
# 0
# 3
# 0
# 1
# 1
# 2
# 0
# 0
# R
# 1
# 29
# 0
# 4
# 22
# 34
# 66
# 39
# 2
# 5
# 1
# 2
# 2
# 2
# 2
# 0
# 0
# https://www.cricbuzz.com/live-cricket-scorecard/114987/gt-vs-pbks-5th-match-indian-premier-league-2025
# R
# 47
# 5
# 97
# 16
# 0
# 20
# 44
# 0
# 1
# 0
# 1
# 0
# 3
# R
# 74
# 33
# 54
# 46
# 6
# 6
# 1
# 2
# 0
# 1
# 1
# 0
# 0
# 0
# https://www.cricbuzz.com/live-cricket-scorecard/114996/rr-vs-kkr-6th-match-indian-premier-league-2025
# R
# 29
# 13
# 25
# 8
# 4
# 33
# 9
# 7
# 16
# 1
# 2
# 1
# 2
# 2
# 2
# 2
# R
# 5
# 97
# 18
# 22
# 0
# 0
# 0
# 0
# 1
# 0
# 0

# %%
url = 'https://www.cricbuzz.com/api/cricket-match/91609/full-commentary/2'
response = requests.get(url=url) 
API_Data = response.json() 
for key in API_Data: 
    print(key)
# Out:
# matchId
# commentary
# commentarySnippetList
# matchDetails

# %%
for item in API_Data["commentary"]:
    print("inningsId:", item["inningsId"])
    for val in item["commentaryList"]:
        if "overSeparator" in val:
            out = val["overSeparator"]["runs"]
            out_type =  "Even" if out % 2 == 0 else "odd"
            print(val["overNumber"], out, out_type )
# Out:
# inningsId: 2
# 19.6 7 odd
# 18.6 11 odd
# 17.6 9 odd
# 16.6 7 odd
# 15.6 14 Even
# 14.6 11 odd
# 13.6 1 odd
# 12.6 2 Even
# 11.6 2 Even
# 10.6 3 odd
# 9.6 4 Even
# 8.6 6 Even
# 7.6 6 Even
# 6.6 9 odd
# 5.6 16 Even
# 4.6 15 odd
# 3.6 5 odd
# 2.6 2 Even
# 1.6 7 odd
# 0.6 2 Even

# %%
comm_url = [line.strip() for line in open("commentry_urls", "r")]
comm_url
# Out:
# ['https://www.cricbuzz.com/api/cricket-match/89731/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/89763/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91398/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91425/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/91596/full-commentary/1',
#  'https://www.cricbuzz.com/api/cricket-match/89731/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/89763/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91398/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91425/full-commentary/2',
#  'https://www.cricbuzz.com/api/cricket-match/91596/full-commentary/2']

# %%
for url in comm_url:
    response = requests.get(url=url)
    API_Data = response.json()
    for item in API_Data["commentary"]:
        print("inningsId:", item["inningsId"])
        for val in item["commentaryList"]:
            if "overSeparator" in val:
                out = val["overSeparator"]["runs"]
                out_type =  "Even" if out % 2 == 0 else "odd"
                print(val["overNumber"], out, out_type )
# Out:
# inningsId: 1
# 19.6 10 Even
# 18.6 1 odd
# 17.6 2 Even
# 16.6 1 odd
# 15.6 9 odd
# 14.6 5 odd
# 13.6 2 Even
# 12.6 6 Even
# 11.6 6 Even
# 10.6 6 Even
# 9.6 2 Even
# 8.6 10 Even
# 7.6 6 Even
# 6.6 13 odd
# 5.6 16 Even
# 4.6 10 Even
# 3.6 4 Even
# 2.6 3 odd
# 1.6 12 Even
# 0.6 1 odd
# inningsId: 1
# 19.6 32 Even
# 18.6 19 odd
# 17.6 16 Even
# 16.6 17 odd
# 15.6 12 Even
# 14.6 7 odd
# 13.6 8 Even
# 12.6 3 odd
# 11.6 7 odd
# 10.6 8 Even
# 9.6 13 odd
# 8.6 8 Even
# 7.6 4 Even
# 6.6 5 odd
# 5.6 15 odd
# 4.6 14 Even
# 3.6 13 odd
# 2.6 12 Even
# 1.6 14 Even
# 0.6 7 odd
# inningsId: 1
# 19.6 19 odd
# 18.6 9 odd
# 17.6 14 Even
# 16.6 5 odd
# 15.6 19 odd
# 14.6 9 odd
# 13.6 10 Even
# 12.6 4 Even
# 11.6 14 Even
# 10.6 4 Even
# 9.6 13 odd
# 8.6 9 odd
# 7.6 13 odd
# 6.6 10 Even
# 5.6 9 odd
# 4.6 7 odd
# 3.6 10 Even
# 2.6 4 Even
# 1.6 7 odd
# 0.6 7 odd
# inningsId: 1
# 19.6 26 Even
# 18.6 7 odd
# 17.6 12 Even
# 16.6 10 Even
# 15.6 2 Even
# 14.6 17 odd
# 13.6 22 Even
# 12.6 8 Even
# 11.6 10 Even
# 10.6 12 Even
# 9.6 15 odd
# 8.6 4 Even
# 7.6 9 odd
# 6.6 4 Even
# 5.6 10 Even
# 4.6 14 Even
# 3.6 6 Even
# 2.6 9 odd
# 1.6 3 odd
# 0.6 6 Even
# inningsId: 1
# 18.6 12 Even
# 17.6 2 Even
# 16.6 20 Even
# 15.6 5 odd
# 14.6 7 odd
# 13.6 12 Even
# 12.6 3 odd
# 11.6 15 odd
# 10.6 8 Even
# 9.6 11 odd
# 8.6 4 Even
# 7.6 8 Even
# 6.6 3 odd
# 5.6 6 Even
# 4.6 14 Even
# 3.6 9 odd
# 2.6 12 Even
# 1.6 2 Even
# 0.6 14 Even
# inningsId: 2
# 14.6 10 Even
# 13.6 7 odd
# 12.6 7 odd
# 11.6 3 odd
# 10.6 11 odd
# 9.6 5 odd
# 8.6 8 Even
# 7.6 10 Even
# 6.6 4 Even
# 5.6 2 Even
# 4.6 3 odd
# 3.6 11 odd
# 2.6 13 odd
# 1.6 7 odd
# 0.6 10 Even
# inningsId: 2
# 19.6 4 Even
# 18.6 21 odd
# 17.6 8 Even
# 16.6 19 odd
# 15.6 9 odd
# 14.6 6 Even
# 13.6 11 odd
# 12.6 16 Even
# 11.6 4 Even
# 10.6 13 odd
# 9.6 10 Even
# 8.6 15 odd
# 7.6 16 Even
# 6.6 7 odd
# 5.6 13 odd
# 4.6 9 odd
# 3.6 9 odd
# 2.6 4 Even
# 1.6 4 Even
# 0.6 7 odd
# inningsId: 2
# 14.6 7 odd
# 13.6 12 Even
# 12.6 18 Even
# 11.6 16 Even
# 10.6 24 Even
# 9.6 8 Even
# 8.6 11 odd
# 7.6 8 Even
# 6.6 12 Even
# 5.6 17 odd
# 4.6 23 odd
# 3.6 9 odd
# 2.6 14 Even
# 1.6 7 odd
# 0.6 2 Even
# inningsId: 2
# 19.6 13 odd
# 18.6 13 odd
# 17.6 6 Even
# 16.6 19 odd
# 15.6 3 odd
# 14.6 2 Even
# 13.6 6 Even
# 12.6 6 Even
# 11.6 10 Even
# 10.6 18 Even
# 9.6 9 odd
# 8.6 6 Even
# 7.6 5 odd
# 6.6 7 odd
# 5.6 10 Even
# 4.6 15 odd
# 3.6 13 odd
# 2.6 12 Even
# 1.6 8 Even
# 0.6 5 odd
# inningsId: 2
# 17.6 11 odd
# 16.6 3 odd
# 15.6 5 odd
# 14.6 9 odd
# 13.6 20 Even
# 12.6 8 Even
# 11.6 11 odd
# 10.6 4 Even
# 9.6 6 Even
# 8.6 7 odd
# 7.6 5 odd
# 6.6 3 odd
# 5.6 5 odd
# 4.6 3 odd
# 3.6 13 odd
# 2.6 9 odd
# 1.6 10 Even
# 0.6 6 Even
